# %% [markdown]
# # Reliability & Validity
#
# **Research Question:** RQ2 (H2): Is the seven-dimension instrument reliable and valid? Cronbach's alpha, ICC against expert ratings, convergent validity vs. solve count. Dimensionality is RQ3, in notebook 04.

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.insert(0, "../platform/orchestrator")
from app.validation_service import compute_icc, compute_cronbach_alpha, compute_convergent_validity, DIMENSIONS

# %% [markdown]
# ## ICC per Dimension

# %%
results = {dim: compute_icc(dim) for dim in DIMENSIONS}
import pandas as pd
pd.DataFrame(results).T[["icc","interpretation","n_subjects","n_raters"]]

# %% [markdown]
# ## Cronbach's Alpha

# %%
compute_cronbach_alpha()

# %% [markdown]
# ## Convergent Validity (solve count)

# %%
compute_convergent_validity("solve_count")
