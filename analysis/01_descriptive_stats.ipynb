# %% [markdown]
# # Descriptive Statistics
#
# **Research Question:** RQ0: What are the demographic and performance characteristics of participants?

# %% [markdown]
# > ⚠️ **PLACEHOLDER NOTEBOOK — NOT FOR PUBLICATION**
# >
# > This notebook currently loads **synthetic fixture data** from `tests/fixtures/` for development purposes only.
# > The fixture data is a mix of simulation output and test sessions — it is **NOT real participant data**.
# >
# > This notebook must be re-run against IRB-approved data from `data/` after collection completes (June 2026).
# > All results, numbers, and figures produced by this notebook before that point are **invalid for any manuscript or report**.

# %%
import pandas as pd
import numpy as np

# SYNTHETIC FIXTURES — replace with ../data/ paths after IRB-approved data collection
skill_scores = pd.read_csv("../tests/fixtures/synthetic_sample_skills.csv")
events = pd.read_csv("../tests/fixtures/synthetic_sample_events.csv")
surveys = pd.read_csv("../tests/fixtures/synthetic_sample_survey.csv")

# %% [markdown]
# ## Table 1 — Participant Summary

# %%
print("Total participants:", skill_scores["participant_code"].nunique())
print(skill_scores.groupby("condition")["participant_code"].nunique())

# %% [markdown]
# ## Skill Score Distribution

# %%
skill_cols = ["accuracy","persistence","web_recon","protocol","ssh_pivot","blue_analysis","time_efficiency"]
skill_scores[skill_cols].describe().round(2)
